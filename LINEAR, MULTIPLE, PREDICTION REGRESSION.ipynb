# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import statsmodels.api as sm

# %%
data=pd.read_csv('29587970-1.01.Simple-linear-regression.csv')
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %%
y=data['GPA']
x1=data['SAT']

# %%
plt.scatter(x1,y)
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.show()

# %%
x=sm.add_constant(x1)
result=sm.OLS(y,x).fit()
result.summary()
# Out:
# C:\Users\My Acer\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Sun, 07 Oct 2040   Prob (F-statistic):           7.20e-11
# Time:                        17:20:23   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
plt.scatter(x1,y,c='green')
yhat=0.0017*x1+0.2570
plt.plot(x1,yhat,lw=4,c='orange',label='regression line')
plt.xlabel('SAT',fontsize=20)
plt.ylabel('GPA',fontsize=20)
plt.show()

# %%
data2=pd.read_csv('29588058-1.02.Multiple-linear-regression.csv')
data2
# Out:
#      SAT   GPA  Rand 1,2,3
# 0   1714  2.40           1
# 1   1664  2.52           3
# 2   1760  2.54           3
# 3   1685  2.74           3
# 4   1693  2.83           2
# ..   ...   ...         ...
# 79  1936  3.71           3
# 80  1810  3.71           1
# 81  1987  3.73           3
# 82  1962  3.76           1
# 83  2050  3.81           2
#
# [84 rows x 3 columns]

# %%
data2.describe()
# Out:
#                SAT        GPA  Rand 1,2,3
# count    84.000000  84.000000   84.000000
# mean   1845.273810   3.330238    2.059524
# std     104.530661   0.271617    0.855192
# min    1634.000000   2.400000    1.000000
# 25%    1772.000000   3.190000    1.000000
# 50%    1846.000000   3.380000    2.000000
# 75%    1934.000000   3.502500    3.000000
# max    2050.000000   3.810000    3.000000

# %%
y=data2['GPA']
x1=data2[['SAT','Rand 1,2,3']]

# %%
x= sm.add_constant(x1)
result2=sm.OLS(y,x).fit()
result2.summary()
# Out:
# C:\Users\My Acer\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.407
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     27.76
# Date:                Sun, 07 Oct 2040   Prob (F-statistic):           6.58e-10
# Time:                        17:20:24   Log-Likelihood:                 12.720
# No. Observations:                  84   AIC:                            -19.44
# Df Residuals:                      81   BIC:                            -12.15
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
yhat=0.0017*data2['SAT']+0.2960
yhat
# Out:
# 0     3.2098
# 1     3.1248
# 2     3.2880
# 3     3.1605
# 4     3.1741
#        ...
# 79    3.5872
# 80    3.3730
# 81    3.6739
# 82    3.6314
# 83    3.7810
# Name: SAT, Length: 84, dtype: float64

# %%
plt.plot(yhat)
plt.show()

# %%
data3=pd.read_csv('29588090-1.03.Dummies.csv')
data3
# Out:
#      SAT   GPA Attendance
# 0   1714  2.40         No
# 1   1664  2.52         No
# 2   1760  2.54         No
# 3   1685  2.74         No
# 4   1693  2.83         No
# ..   ...   ...        ...
# 79  1936  3.71        Yes
# 80  1810  3.71        Yes
# 81  1987  3.73         No
# 82  1962  3.76        Yes
# 83  2050  3.81        Yes
#
# [84 rows x 3 columns]

# %%
new_data=pd.DataFrame({'const':1,'SAT':[1700,1650],'Attendance':[0,1]})
new_data=new_data[['const','SAT','Attendance']]
new_data
# Out:
#    const   SAT  Attendance
# 0      1  1700           0
# 1      1  1650           1

# %%
new_data.rename(index={0:'Bob',1:'Alice'})
# Out:
#        const   SAT  Attendance
# Bob        1  1700           0
# Alice      1  1650           1

# %%
prediction=result2.predict(new_data)
prediction
# Out:
# 0    3.107054
# 1    3.016107
# dtype: float64

# %%
predictionN=pd.DataFrame({'prediction':prediction})
new_data=new_data.join(predictionN)
new_data.rename(index={0:'Bob',1:'Alice'})
# Out:
#        const   SAT  Attendance  prediction
# Bob        1  1700           0    3.107054
# Alice      1  1650           1    3.016107
